# %% [markdown]
# # Analyzing Mortgage & Loan Data
#
# We'll start by importing relevant _libraries_ (i.e. prebuilt chunks of Python that have useful functions).

# %%
import pandas as pd    #data manipulation
import numpy as np     #mathematical operations

import matplotlib.pyplot as plt      #plotting tools

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# We'll be importing data from the [Freddie Mac Database](http://www.freddiemac.com/research/datasets/sf_loanlevel_dataset.page) as a pandas dataframe.  We will need

# %%
url = "../Data/Freddie_Mac/2019/historical_data_2019Q1.txt"

file = open(url, 'r')
lines = file.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-49b792fcf196> in <module>()
#       1 url = "../Data/Freddie_Mac/2019/historical_data_2019Q1.txt"
#       2
# ----> 3 file = open(url, 'r')
#       4 lines = file.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data/Freddie_Mac/2019/historical_data_2019Q1.txt'
